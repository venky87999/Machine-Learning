# %% [markdown]
# <a href="https://colab.research.google.com/github/venky87999/Machine-Learning/blob/main/Exp_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/III_I_ML_LAB/housing.csv',usecols =['longitude','latitude','housing_median_age'])
df.head()
# Out:
#    longitude  latitude  housing_median_age
# 0    -122.23     37.88                41.0
# 1    -122.22     37.86                21.0
# 2    -122.24     37.85                52.0
# 3    -122.25     37.85                52.0
# 4    -122.25     37.85                52.0

# %%
import seaborn as sns
sns.scatterplot(data = df, x = 'longitude', y = 'latitude', hue ='median_house_value')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[['longitude','latitude']],df[['housing_median_age']],test_size=0.8,random_state=0)

# %%
from sklearn import preprocessing
X_train_norm = preprocessing.normalize(X_train)
X_test_norm = preprocessing.normalize(X_test)
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 3, random_state = 0, n_init='auto')
kmeans.fit(X_train_norm)
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = kmeans.labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.boxplot(x = kmeans.labels_, y = y_train['housing_median_age'])
# Out:
# <Axes: ylabel='housing_median_age'>

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X_train_norm, kmeans.labels_, metric='euclidean')
K = range(2, 8)
fits = []
score = []
for k in K:
  model = KMeans(n_clusters = k, random_state = 0, n_init='auto').fit(X_train_norm)
  fits.append(model)
  score.append(silhouette_score(X_train_norm, model.labels_, metric='euclidean'))
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = fits[0].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = fits[2].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = fits[2].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.lineplot(x = K, y = score)
# Out:
# <Axes: >

# %%
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = kmeans.labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = X_train, x = 'longitude', y = 'latitude', hue = fits[3].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
